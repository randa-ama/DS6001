# %% [markdown]
# # **DS 6001: Lab Assignment 2**
# ## Randa Ampah and Aniyah McWilliams

# %% [markdown]
# ## *Problem 1*

# %%
import pandas as pd
import numpy as np
import os

os.chdir('/Users/randap/Desktop/MSDS/Fall25/DS6001/labs/lab data')

# %% [markdown]
# ### Part A

# %%
column_names = ["Country", "Happiness score", "Whisker-high", "Whisker-low",
 "Dystopia (1.92) + residual", "Explained by: GDP per capita",
 "Explained by: Social support", "Explained by: Healthy life expectancy",
 "Explained by: Freedom to make life choices", "Explained by: Generosity",
 "Explained by: Perceptions of corruption" ]

data_clean = pd.read_csv('data_clean.csv')

data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     156 non-null    object
#  1   Happiness score                             156 non-null    float64
#  2   Whisker-high                                156 non-null    float64
#  3   Whisker-low                                 156 non-null    float64
#  4   Dystopia (1.92) + residual                  156 non-null    float64
#  5   Explained by: GDP per capita                156 non-null    float64
#  6   Explained by: Social support                156 non-null    float64
#  7   Explained by: Healthy life expectancy       156 non-null    float64
#  8   Explained by: Freedom to make life choices  156 non-null    float64
# ...

# %% [markdown]
# ### Part B

# %%
# data1 = pd.read_csv('data1.csv')
data1 = pd.read_csv('data1.csv', header=2)
data1.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593        7.398
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                         1.305
# 1                       2.383                         1.456
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.592                                  0.874
# 1                         1.582                                  0.861
# ...

# %% [markdown]
# Originally, the dataset did not load correctly. The first 2 rows were informational and not part of the data, but the default for loading csv's is to use the first row as the header. To fix that error, we added the header parameter and set it equal to 2 to use the 3rd row containing the column names.

# %% [markdown]
# ### Part C

# %%
# data2 = pd.read_csv('data2.txt')
data2 = pd.read_csv('data2.txt', header=2, skiprows=[3])
data2.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593        7.398
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                         1.305
# 1                       2.383                         1.456
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.592                                  0.874
# 1                         1.582                                  0.861
# ...

# %% [markdown]
# We decided to use header and skiprows because the row we needed for the column names wasn't the first row and we needed to skip the 4th row due to formatting of the document.

# %% [markdown]
# ### Part D

# %%
#data3 = pd.read_csv('data3.txt')
data3 = pd.read_csv('data3.txt', delim_whitespace=True, header=2)
data3.head()
# Out:
# /var/folders/1z/t_vl0dx95552hzn7xv8z08sm0000gn/T/ipykernel_61556/897544914.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data3 = pd.read_csv('data3.txt', delim_whitespace=True, header=2)
#        Country Happiness  score Whisker-high  Whisker-low  Dystopia  (1.92)  \
# 0      Finland     7.632  7.695        7.569        2.595     1.305   1.592
# 1       Norway     7.594  7.657         7.53        2.383     1.456   1.582
# 2      Denmark     7.555  7.623        7.487        2.370     1.351   1.590
# 3      Iceland     7.495  7.593        7.398        2.426     1.343   1.644
# 4  Switzerland     7.487   7.57        7.405        2.320     1.420   1.549
#
#        +  residual  Explained  ...  life.1  choices  Explained.4  by:.4  \
# 0  0.874     0.681      0.192  ...     NaN      NaN          NaN    NaN
# 1  0.861     0.686      0.286  ...     NaN      NaN          NaN    NaN
# ...

# %% [markdown]
# This txt file was not comma separated, so we had to use the delim_whitespace parameter and set it equal to True, since the column values were separated by spaces.

# %% [markdown]
# ### Part E

# %%
#data4 = pd.read_csv('data4.txt')
data4 = pd.read_csv('data4.txt', sep='$',names=column_names)
data4.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593        7.398
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                         1.305
# 1                       2.383                         1.456
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.592                                  0.874
# 1                         1.582                                  0.861
# ...

# %% [markdown]
# This dataset had no column names, so we had to apply the list from the beginning as the header. It also was separated by dollar signs, so we had to used sep = "$" to change the delimiter.

# %% [markdown]
# ### Part F

# %%
#data5 = pd.read_csv('data5.csv')
data5 = pd.read_csv('data5.csv', skipfooter=2)
data5.tail()
# Out:
# /var/folders/1z/t_vl0dx95552hzn7xv8z08sm0000gn/T/ipykernel_61556/1289507354.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data5 = pd.read_csv('data5.csv', skipfooter=2)
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 151                     Yemen            3.355         3.448        3.262
# 152                  Tanzania            3.303         3.414        3.193
# 153               South Sudan            3.254         3.385        3.123
# 154  Central African Republic            3.083         3.227        2.939
# 155                   Burundi            2.905         3.074        2.735
#
#      Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 151                       1.106                         0.442
# 152                       0.628                         0.455
# ...

# %% [markdown]
# This dataset had unwanted rows at end, so we had to use the skipfooter parameter to remove the 2 rows at the end.

# %% [markdown]
# ### Part G

# %%
# data6 = pd.read_csv('data6.dat')
data6 = pd.read_csv('data6.dat',na_values=[999])
data6.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593          NaN
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                           NaN
# 1                         NaN                           NaN
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           NaN                                    NaN
# 1                         1.582                                    NaN
# ...

# %% [markdown]
# We decided to use the na_values parameter to recognize the 999 values as missing values, because some softwares don't have a specific type of data for missing values so they use numbers sometimes.

# %% [markdown]
# ### Part H

# %%
# data7 = pd.read_excel('data7.xlsx')
data7 = pd.read_excel('data7.xlsx', sheet_name='Data')

data7.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593        7.398
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                         1.305
# 1                       2.383                         1.456
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.592                                  0.874
# 1                         1.582                                  0.861
# ...

# %%
data7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     156 non-null    object
#  1   Happiness score                             156 non-null    float64
#  2   Whisker-high                                156 non-null    float64
#  3   Whisker-low                                 156 non-null    float64
#  4   Dystopia (1.92) + residual                  156 non-null    float64
#  5   Explained by: GDP per capita                156 non-null    float64
#  6   Explained by: Social support                156 non-null    float64
#  7   Explained by: Healthy life expectancy       156 non-null    float64
#  8   Explained by: Freedom to make life choices  156 non-null    float64
# ...

# %% [markdown]
# Microsoft excel gives users the ability to have multiple sheets within a singular comma separated file (csv). This led to an error when trying to read in the data, thus we had to use the parameter sheet_name to properly load in the data. The sheet_name parameter specifies which sheet you want to open which allowed us to properly load in the dataset.

# %% [markdown]
# ### Part I

# %%
data8 = pd.read_stata('data8.dta')
data8.head()
# Out:
#        country  happinessscore  whiskerhigh  whiskerlow  dystopia192residual  \
# 0      Finland           7.632        7.695       7.569                2.595
# 1       Norway           7.594        7.657       7.530                2.383
# 2      Denmark           7.555        7.623       7.487                2.370
# 3      Iceland           7.495        7.593       7.398                2.426
# 4  Switzerland           7.487        7.570       7.405                2.320
#
#    explainedbygdppercapita  explainedbysocialsupport  \
# 0                    1.305                     1.592
# 1                    1.456                     1.582
# 2                    1.351                     1.590
# 3                    1.343                     1.644
# 4                    1.420                     1.549
#
#    explainedbyhealthylifeexpectancy  explainedbyfreedomtomakelifechoi  \
# 0                             0.874                             0.681
# ...

# %%
data8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   country                           156 non-null    object
#  1   happinessscore                    156 non-null    float32
#  2   whiskerhigh                       156 non-null    float32
#  3   whiskerlow                        156 non-null    float32
#  4   dystopia192residual               156 non-null    float32
#  5   explainedbygdppercapita           156 non-null    float32
#  6   explainedbysocialsupport          156 non-null    float32
#  7   explainedbyhealthylifeexpectancy  156 non-null    float32
#  8   explainedbyfreedomtomakelifechoi  156 non-null    float32
#  9   explainedbygenerosity             156 non-null    float32
#  10  explainedbyperceptionsofcorrupti  156 non-null    float32
# dtypes: float32(10), object(1)
# ...

# %% [markdown]
# The dataset loaded correctly. The only differences between this csv and the clean one is that the numberic columns are saved as float32 instead of float64 and that the column names were formatted differently (all lowercase, no spaces or special characters)

# %% [markdown]
# ### Part J

# %%
data9 = pd.read_spss('data9.sav')
data9.head()
# Out:
#        country  happiness  whiskerhigh  whiskerlow  dystopia  gdpPC  \
# 0      Finland      7.632        7.695       7.569     2.595  1.305
# 1       Norway      7.594        7.657       7.530     2.383  1.456
# 2      Denmark      7.555        7.623       7.487     2.370  1.351
# 3      Iceland      7.495        7.593       7.398     2.426  1.343
# 4  Switzerland      7.487        7.570       7.405     2.320  1.420
#
#    socsupport  lifeexp  lifechoice  generous  corrupt
# 0       1.592    0.874       0.681     0.192    0.393
# 1       1.582    0.861       0.686     0.286    0.340
# 2       1.590    0.868       0.683     0.284    0.408
# 3       1.644    0.914       0.677     0.353    0.138
# 4       1.549    0.927       0.660     0.256    0.357

# %% [markdown]
# This dataset loaded correctly. The column names just formatted differently (all lowercase, no spaces or special characters).

# %%
data9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      156 non-null    object
#  1   happiness    156 non-null    float64
#  2   whiskerhigh  156 non-null    float64
#  3   whiskerlow   156 non-null    float64
#  4   dystopia     156 non-null    float64
#  5   gdpPC        156 non-null    float64
#  6   socsupport   156 non-null    float64
#  7   lifeexp      156 non-null    float64
#  8   lifechoice   156 non-null    float64
#  9   generous     156 non-null    float64
#  10  corrupt      156 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 13.5+ KB

# %%
data9.tail()
# Out:
#                       country  happiness  whiskerhigh  whiskerlow  dystopia  \
# 151                     Yemen      3.355        3.448       3.262     1.106
# 152                  Tanzania      3.303        3.414       3.193     0.628
# 153               South Sudan      3.254        3.385       3.123     1.691
# 154  Central African Republic      3.083        3.227       2.939     2.487
# 155                   Burundi      2.905        3.074       2.735     1.752
#
#      gdpPC  socsupport  lifeexp  lifechoice  generous  corrupt
# 151  0.442       1.073    0.343       0.244     0.083    0.064
# 152  0.455       0.991    0.381       0.481     0.270    0.097
# 153  0.337       0.608    0.177       0.112     0.224    0.106
# 154  0.024       0.000    0.010       0.305     0.218    0.038
# 155  0.091       0.627    0.145       0.065     0.149    0.076

# %% [markdown]
# ### Part K

# %%
data10 = pd.read_sas('data10.xpt', encoding='latin-1')
data10.head()
# Out:
#        COUNTRY  HAPPINES  WHISKERH  WHISKERL  DYSTOPIA  EXPLAINE  EXPLAIN2  \
# 0      Finland     7.632     7.695     7.569     2.595     1.305     1.592
# 1       Norway     7.594     7.657     7.530     2.383     1.456     1.582
# 2      Denmark     7.555     7.623     7.487     2.370     1.351     1.590
# 3      Iceland     7.495     7.593     7.398     2.426     1.343     1.644
# 4  Switzerland     7.487     7.570     7.405     2.320     1.420     1.549
#
#    EXPLAIN3  EXPLAIN4  EXPLAIN5  EXPLAIN6
# 0     0.874     0.681     0.192     0.393
# 1     0.861     0.686     0.286     0.340
# 2     0.868     0.683     0.284     0.408
# 3     0.914     0.677     0.353     0.138
# 4     0.927     0.660     0.256     0.357

# %%
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   COUNTRY   156 non-null    object
#  1   HAPPINES  156 non-null    float64
#  2   WHISKERH  156 non-null    float64
#  3   WHISKERL  156 non-null    float64
#  4   DYSTOPIA  156 non-null    float64
#  5   EXPLAINE  156 non-null    float64
#  6   EXPLAIN2  156 non-null    float64
#  7   EXPLAIN3  156 non-null    float64
#  8   EXPLAIN4  156 non-null    float64
#  9   EXPLAIN5  156 non-null    float64
#  10  EXPLAIN6  156 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# This dataset loaded correctly. The column names just formatted differently (all uppercase, no special characters).

# %% [markdown]
# ### Part L

# %%
d11_widths = pd.read_csv('data11_width - Sheet1.csv')
d11_widths
# Out:
#     Feature  Width
# 0         1     24
# 1         2      5
# 2         3      5
# 3         4      5
# 4         5      5
# 5         6      5
# 6         7      5
# 7         8      5
# 8         9      5
# 9        10      5
# 10       11      5

# %%
data11 = pd.read_fwf('data11.txt', widths= d11_widths['Width'], names=column_names)
data11.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Finland            7.632         7.695        7.569
# 1       Norway            7.594         7.657        7.530
# 2      Denmark            7.555         7.623        7.487
# 3      Iceland            7.495         7.593        7.398
# 4  Switzerland            7.487         7.570        7.405
#
#    Dystopia (1.92) + residual  Explained by: GDP per capita  \
# 0                       2.595                         1.305
# 1                       2.383                         1.456
# 2                       2.370                         1.351
# 3                       2.426                         1.343
# 4                       2.320                         1.420
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.592                                  0.874
# 1                         1.582                                  0.861
# ...

# %%
data11.to_csv('/Users/randap/Desktop/MSDS/Fall25/DS6001/labs/lab data/data11.csv')

# %% [markdown]
# ## *Problem 2*

# %% [markdown]
# ### Part A

# %%
epa = pd.read_excel('epa_data.xlsx', sheet_name=None)

# %%
epa['CALE 2011']
# Out:
#     Species  Year    site  Plot  trt        Treatment  cover0  arsincover0  \
# 0      CALE  2011  Hyslop     2    6      Roundup 0.2     0.2     0.044736
# 1      CALE  2011  Hyslop     6    1  Carrier Control     0.7     0.083764
# 2      CALE  2011  Hyslop    12    4       Banvel 0.2     0.7     0.083764
# 3      CALE  2011  Hyslop    13    2         No Spray     0.6     0.077537
# 4      CALE  2011  Hyslop    17    2         No Spray     0.5     0.070770
# ..      ...   ...     ...   ...  ...              ...     ...          ...
# 123    CALE  2011  Botany   370    8    Rdup+Bnvl 0.2     1.0     0.100167
# 124    CALE  2011  Botany   377    3       Banvel 0.1     4.0     0.201358
# 125    CALE  2011  Botany   379    4       Banvel 0.2     0.5     0.070770
# 126    CALE  2011  Botany   380    2         No Spray     0.3     0.054800
# 127    CALE  2011  Botany   382    4       Banvel 0.2     0.2     0.044736
#
# ...

# %% [markdown]
# ## Part B

# %%
epa.keys()
# Out:
# dict_keys(['CALE 2010', 'CALE 2011', 'ELGL 2010', 'ELGL 2011', 'ERLA 2010', 'ERLA 2011', 'FEID 2010', 'FEID 2011', 'FRVI 2010', 'FRVI 2011', 'IRTE 2010', 'IRTE 2011', 'POGR 2010', 'POGR 2011', 'PRVU 2010', 'PRVU 2011', 'RAOC 2010', 'RAOC 2011', 'Solution Chemistry', 'ReadMe'])

# %%
del epa['Solution Chemistry']
del epa['ReadMe']

# %%
epa.keys()
# Out:
# dict_keys(['CALE 2010', 'CALE 2011', 'ELGL 2010', 'ELGL 2011', 'ERLA 2010', 'ERLA 2011', 'FEID 2010', 'FEID 2011', 'FRVI 2010', 'FRVI 2011', 'IRTE 2010', 'IRTE 2011', 'POGR 2010', 'POGR 2011', 'PRVU 2010', 'PRVU 2011', 'RAOC 2010', 'RAOC 2011'])

# %% [markdown]
# ## Part C

# %%
for df in epa.keys():
    epa[df].columns = epa[df].columns.str.lower().str.strip()

# %% [markdown]
# ## Part D

# %%
big_epa = pd.concat(epa, ignore_index = True)

# %%
big_epa.head()
# Out:
#    year species    site  plot  trt        treatment  pods  sqrtpods  cover0  \
# 0  2010    CALE  Hyslop     4    6      Roundup 0.1   1.0  1.000000     1.0
# 1  2010    CALE  Hyslop    12    7   Rdup/Bnvl 0.01   6.0  2.449490     2.0
# 2  2010    CALE  Hyslop    13    5     Roundup 0.01   8.0  2.828427     2.0
# 3  2010    CALE  Hyslop    15    1  Carrier Control   3.0  1.732051     1.0
# 4  2010    CALE  Hyslop    17    3      Banvel 0.01   0.0  0.000000     1.0
#
#    arsincover0  ...  totseeddw  infloroescences  sqrtinfluorescences  \
# 0     0.100167  ...        NaN              NaN                  NaN
# 1     0.141897  ...        NaN              NaN                  NaN
# 2     0.141897  ...        NaN              NaN                  NaN
# 3     0.100167  ...        NaN              NaN                  NaN
# 4     0.100167  ...        NaN              NaN                  NaN
#
#    atypicalinfluorescences  sqrtatypicalinfluorescences  totalinflorescence  \
# ...

# %%
big_epa.tail()
# Out:
#       year species    site  plot  trt      treatment  pods  sqrtpods  cover0  \
# 2299  2011    RAOC  Botany   370    8  Rdup+Bnvl 0.2   NaN       NaN     0.2
# 2300  2011    RAOC  Botany   377    3     Banvel 0.1   NaN       NaN     0.5
# 2301  2011    RAOC  Botany   379    4     Banvel 0.2   NaN       NaN     0.3
# 2302  2011    RAOC  Botany   380    2       No Spray   NaN       NaN     NaN
# 2303  2011    RAOC  Botany   382    4     Banvel 0.2   NaN       NaN     0.2
#
#       arsincover0  ...  totseeddw  infloroescences  sqrtinfluorescences  \
# 2299     0.044736  ...        NaN              NaN                  NaN
# 2300     0.070770  ...        NaN              NaN                  NaN
# 2301     0.054800  ...        NaN              NaN                  NaN
# 2302          NaN  ...        NaN              NaN                  NaN
# 2303     0.044736  ...        NaN              NaN                  NaN
#
#       atypicalinfluorescences  sqrtatypicalinfluorescences  \
# ...

# %% [markdown]
# ## Part E

# %%
cols_to_keep = ['year', 'species', 'site', 'plot', 'trt', 'treatment',
 'pods', 'cover0', 'arsincover0', 'cover3', 'arsincover3',
 'cover5', 'arsincover5']

big_epa.to_csv('/Users/randap/Desktop/MSDS/Fall25/DS6001/labs/lab data/big_epa.csv',columns=cols_to_keep)
